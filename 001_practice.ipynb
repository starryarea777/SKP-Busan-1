# %% [markdown]
# # 변수
#
# 면수는 메모리상 지정된 값을 가리키는 이름입니다.

# %%
print("hello!")
# Out:
# hello!

# %% [markdown]
# * 변수를 만드는 방법: a = 10 => 변수의 초기화
# a라는 변수에 10이라는  값을 할당(allocate)

# %%
a = "c"
print(a)

c = "a"
print(c)

# 오류 때문에 변수를 영어로
# Out:
# c
# a

# %%
## 변수의 명명규칙
### 숫자, 특수문자는 첫번째 올 수 없다!(_제외)
### ex

1apple = "apple"
# Out:
#   Cell In[19], line 5
#     1apple = "apple"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ##### 띄어씌기 되는 곳(단어가 시작되는 곳)은 대문자, '_' 가능
# * ex. iamhungry
# iAmHungry
# i_am_hungry => 주로 python에서 사용

# %%
## 'for'는 단독으로 쓸 수 없음
### _for로 사용 가능

import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
apple = 10
print(apple)

apple = 1000 
print(apple)
# reallocate
# Out:
# 10
# 1000
